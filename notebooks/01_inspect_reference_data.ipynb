# %% [markdown]
# # Inspect H37Rv Reference Data
#
# This notebook checks the downloaded *Mycobacterium tuberculosis* H37Rv reference genome and annotation files before they are used in the domain-level Tn-seq visualisation pipeline.

# %%
from pathlib import Path
import sys

print("Python version:", sys.version)
print("Python executable:", sys.executable)

# %%
for path in raw_data_dir.rglob("*"):
    if path.is_file():
        print(path.relative_to(project_root))

# %%
assembly_dir = (
    raw_data_dir
    / "ncbi_dataset"
    / "ncbi_dataset"
    / "data"
    / "GCF_000195955.2"
)

fasta_file = assembly_dir / "GCF_000195955.2_ASM19595v2_genomic.fna"
gff_file = assembly_dir / "genomic.gff"

print("FASTA exists:", fasta_file.exists(), fasta_file)
print("GFF exists:", gff_file.exists(), gff_file)

# %%
from pathlib import Path

project_root = Path.cwd().parent
raw_data_dir = project_root / "data" / "raw"

print("Current notebook location:", Path.cwd())
print("Project root:", project_root)
print("Raw data directory:", raw_data_dir)
print("Raw data directory exists:", raw_data_dir.exists())
